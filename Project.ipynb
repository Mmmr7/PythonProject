# %%
import pandas as pd
# Open and reshape.
data = pd.read_csv('datasets/stackoverflow/stackOverFlow.csv', index_col = 0)
data = data[['Country', 'Student', 'Employment', 'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType', 'YearsCoding', 'JobSatisfaction', 'CareerSatisfaction', 'HopeFiveYears', 'JobSearchStatus', 'LastNewJob', 'SalaryType', 'ConvertedSalary', 'LanguageWorkedWith', 'OperatingSystem', 'NumberMonitors', 'StackOverflowRecommend', 'StackOverflowVisit', 'HoursComputer', 'HoursOutside', 'Age']]
print(data.shape[0])
print(data.shape[1])
data
# Out:
# /Users/olegsidorenkov/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 98855
# 23
#                        Country         Student  \
# Respondent
# 1                        Kenya              No
# 3               United Kingdom              No
# 4                United States              No
# 5                United States              No
# 7                 South Africa  Yes, part-time
# ...                        ...             ...
# 101513           United States             NaN
# 101531                   Spain  Yes, full-time
# 101541                   India  Yes, full-time
# 101544      Russian Federation              No
# 101548                Cambodia             NaN
#
#                                                    Employment  \
# Respondent
# 1                                          Employed part-time
# 3                                          Employed full-time
# 4                                          Employed full-time
# 5                                          Employed full-time
# 7                                          Employed full-time
# ...                                                       ...
# 101513                                                    NaN
# 101531                     Not employed, but looking for work
# 101541                                     Employed full-time
# 101544      Independent contractor, freelancer, or self-em...
# 101548                                                    NaN
#
#                                               FormalEducation  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                                            Associate degree
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7           Some college/university study without earning ...
# ...                                                       ...
# 101513                                                    NaN
# 101531                                                    NaN
# 101541               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 101544      Some college/university study without earning ...
# 101548                                                    NaN
#
#                                                UndergradMajor  \
# Respondent
# 1                                   Mathematics or statistics
# 3           A natural science (ex. biology, chemistry, phy...
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 7           Computer science, computer engineering, or sof...
# ...                                                       ...
# 101513                                                    NaN
# 101531                                                    NaN
# 101541                                                    NaN
# 101544                                                    NaN
# 101548                                                    NaN
#
#                          CompanySize  \
# Respondent
# 1                 20 to 99 employees
# 3           10,000 or more employees
# 4                 20 to 99 employees
# 5               100 to 499 employees
# 7           10,000 or more employees
# ...                              ...
# 101513                           NaN
# 101531                           NaN
# 101541                           NaN
# 101544                           NaN
# 101548                           NaN
#
#                                                       DevType  \
# Respondent
# 1                                        Full-stack developer
# 3           Database administrator;DevOps specialist;Full-...
# 4                    Engineering manager;Full-stack developer
# 5                                        Full-stack developer
# 7           Data or business analyst;Desktop or enterprise...
# ...                                                       ...
# 101513                                                    NaN
# 101531                 Back-end developer;Front-end developer
# 101541                                                    NaN
# 101544                                                    NaN
# 101548                                                    NaN
#
#                  YearsCoding                     JobSatisfaction  \
# Respondent
# 1                  3-5 years                 Extremely satisfied
# 3           30 or more years             Moderately dissatisfied
# 4                24-26 years                Moderately satisfied
# 5                18-20 years  Neither satisfied nor dissatisfied
# 7                  6-8 years                  Slightly satisfied
# ...                      ...                                 ...
# 101513                   NaN                                 NaN
# 101531             0-2 years                                 NaN
# 101541                   NaN                                 NaN
# 101544                   NaN                                 NaN
# 101548                   NaN                                 NaN
#
#                             CareerSatisfaction  ... SalaryType  \
# Respondent                                      ...
# 1                          Extremely satisfied  ...    Monthly
# 3           Neither satisfied nor dissatisfied  ...     Yearly
# 4                         Moderately satisfied  ...        NaN
# 5                        Slightly dissatisfied  ...        NaN
# 7                         Moderately satisfied  ...     Yearly
# ...                                        ...  ...        ...
# 101513                                     NaN  ...        NaN
# 101531                                     NaN  ...        NaN
# 101541                                     NaN  ...        NaN
# 101544                                     NaN  ...        NaN
# 101548                                     NaN  ...        NaN
#
#            ConvertedSalary                                LanguageWorkedWith  \
# Respondent
# 1                      NaN                        JavaScript;Python;HTML;CSS
# 3                  70841.0                      JavaScript;Python;Bash/Shell
# 4                      NaN                                               NaN
# 5                      NaN  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 7                  21426.0                C;C++;Java;Matlab;R;SQL;Bash/Shell
# ...                    ...                                               ...
# 101513                 NaN                                               NaN
# 101531                 NaN                                               NaN
# 101541                 NaN                                               NaN
# 101544                 NaN                                               NaN
# 101548                 NaN                                               NaN
#
#            OperatingSystem  NumberMonitors StackOverflowRecommend  \
# Respondent
# 1              Linux-based               1       10 (Very Likely)
# 3              Linux-based               2       10 (Very Likely)
# 4                      NaN             NaN                    NaN
# 5                  Windows               2       10 (Very Likely)
# 7                  Windows               2       10 (Very Likely)
# ...                    ...             ...                    ...
# 101513                 NaN             NaN                    NaN
# 101531                 NaN             NaN                    NaN
# 101541                 NaN             NaN                    NaN
# 101544                 NaN             NaN                    NaN
# 101548                 NaN             NaN                    NaN
#
#                          StackOverflowVisit  HoursComputer  \
# Respondent
# 1                    Multiple times per day   9 - 12 hours
# 3           A few times per month or weekly    5 - 8 hours
# 4                                       NaN            NaN
# 5                      A few times per week   9 - 12 hours
# 7                     Daily or almost daily  Over 12 hours
# ...                                     ...            ...
# 101513                                  NaN            NaN
# 101531                                  NaN            NaN
# 101541                                  NaN            NaN
# 101544                                  NaN            NaN
# 101548                                  NaN            NaN
#
#                     HoursOutside                Age
# Respondent
# 1                    1 - 2 hours  25 - 34 years old
# 3                30 - 59 minutes  35 - 44 years old
# 4                            NaN                NaN
# 5           Less than 30 minutes  35 - 44 years old
# 7                    1 - 2 hours  18 - 24 years old
# ...                          ...                ...
# 101513                       NaN                NaN
# 101531                       NaN                NaN
# 101541                       NaN                NaN
# 101544                       NaN                NaN
# 101548                       NaN                NaN
#
# [98855 rows x 23 columns]

# %%
# Chages string to boolean.
data['Student'] = data['Student'].replace(['Yes, part-time', 'Yes, full-time'], True)
data['Student'] = data['Student'].replace('No', False)
data
# Out:
#                        Country Student  \
# Respondent
# 1                        Kenya   False
# 3               United Kingdom   False
# 4                United States   False
# 5                United States   False
# 7                 South Africa    True
# ...                        ...     ...
# 101513           United States     NaN
# 101531                   Spain    True
# 101541                   India    True
# 101544      Russian Federation   False
# 101548                Cambodia     NaN
#
#                                                    Employment  \
# Respondent
# 1                                          Employed part-time
# 3                                          Employed full-time
# 4                                          Employed full-time
# 5                                          Employed full-time
# 7                                          Employed full-time
# ...                                                       ...
# 101513                                                    NaN
# 101531                     Not employed, but looking for work
# 101541                                     Employed full-time
# 101544      Independent contractor, freelancer, or self-em...
# 101548                                                    NaN
#
#                                               FormalEducation  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                                            Associate degree
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7           Some college/university study without earning ...
# ...                                                       ...
# 101513                                                    NaN
# 101531                                                    NaN
# 101541               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 101544      Some college/university study without earning ...
# 101548                                                    NaN
#
#                                                UndergradMajor  \
# Respondent
# 1                                   Mathematics or statistics
# 3           A natural science (ex. biology, chemistry, phy...
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 7           Computer science, computer engineering, or sof...
# ...                                                       ...
# 101513                                                    NaN
# 101531                                                    NaN
# 101541                                                    NaN
# 101544                                                    NaN
# 101548                                                    NaN
#
#                          CompanySize  \
# Respondent
# 1                 20 to 99 employees
# 3           10,000 or more employees
# 4                 20 to 99 employees
# 5               100 to 499 employees
# 7           10,000 or more employees
# ...                              ...
# 101513                           NaN
# 101531                           NaN
# 101541                           NaN
# 101544                           NaN
# 101548                           NaN
#
#                                                       DevType  \
# Respondent
# 1                                        Full-stack developer
# 3           Database administrator;DevOps specialist;Full-...
# 4                    Engineering manager;Full-stack developer
# 5                                        Full-stack developer
# 7           Data or business analyst;Desktop or enterprise...
# ...                                                       ...
# 101513                                                    NaN
# 101531                 Back-end developer;Front-end developer
# 101541                                                    NaN
# 101544                                                    NaN
# 101548                                                    NaN
#
#                  YearsCoding                     JobSatisfaction  \
# Respondent
# 1                  3-5 years                 Extremely satisfied
# 3           30 or more years             Moderately dissatisfied
# 4                24-26 years                Moderately satisfied
# 5                18-20 years  Neither satisfied nor dissatisfied
# 7                  6-8 years                  Slightly satisfied
# ...                      ...                                 ...
# 101513                   NaN                                 NaN
# 101531             0-2 years                                 NaN
# 101541                   NaN                                 NaN
# 101544                   NaN                                 NaN
# 101548                   NaN                                 NaN
#
#                             CareerSatisfaction  ... SalaryType  \
# Respondent                                      ...
# 1                          Extremely satisfied  ...    Monthly
# 3           Neither satisfied nor dissatisfied  ...     Yearly
# 4                         Moderately satisfied  ...        NaN
# 5                        Slightly dissatisfied  ...        NaN
# 7                         Moderately satisfied  ...     Yearly
# ...                                        ...  ...        ...
# 101513                                     NaN  ...        NaN
# 101531                                     NaN  ...        NaN
# 101541                                     NaN  ...        NaN
# 101544                                     NaN  ...        NaN
# 101548                                     NaN  ...        NaN
#
#            ConvertedSalary                                LanguageWorkedWith  \
# Respondent
# 1                      NaN                        JavaScript;Python;HTML;CSS
# 3                  70841.0                      JavaScript;Python;Bash/Shell
# 4                      NaN                                               NaN
# 5                      NaN  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 7                  21426.0                C;C++;Java;Matlab;R;SQL;Bash/Shell
# ...                    ...                                               ...
# 101513                 NaN                                               NaN
# 101531                 NaN                                               NaN
# 101541                 NaN                                               NaN
# 101544                 NaN                                               NaN
# 101548                 NaN                                               NaN
#
#            OperatingSystem  NumberMonitors StackOverflowRecommend  \
# Respondent
# 1              Linux-based               1       10 (Very Likely)
# 3              Linux-based               2       10 (Very Likely)
# 4                      NaN             NaN                    NaN
# 5                  Windows               2       10 (Very Likely)
# 7                  Windows               2       10 (Very Likely)
# ...                    ...             ...                    ...
# 101513                 NaN             NaN                    NaN
# 101531                 NaN             NaN                    NaN
# 101541                 NaN             NaN                    NaN
# 101544                 NaN             NaN                    NaN
# 101548                 NaN             NaN                    NaN
#
#                          StackOverflowVisit  HoursComputer  \
# Respondent
# 1                    Multiple times per day   9 - 12 hours
# 3           A few times per month or weekly    5 - 8 hours
# 4                                       NaN            NaN
# 5                      A few times per week   9 - 12 hours
# 7                     Daily or almost daily  Over 12 hours
# ...                                     ...            ...
# 101513                                  NaN            NaN
# 101531                                  NaN            NaN
# 101541                                  NaN            NaN
# 101544                                  NaN            NaN
# 101548                                  NaN            NaN
#
#                     HoursOutside                Age
# Respondent
# 1                    1 - 2 hours  25 - 34 years old
# 3                30 - 59 minutes  35 - 44 years old
# 4                            NaN                NaN
# 5           Less than 30 minutes  35 - 44 years old
# 7                    1 - 2 hours  18 - 24 years old
# ...                          ...                ...
# 101513                       NaN                NaN
# 101531                       NaN                NaN
# 101541                       NaN                NaN
# 101544                       NaN                NaN
# 101548                       NaN                NaN
#
# [98855 rows x 23 columns]

# %%
# Gets data info.
counter = 0
data['NumberMonitors'] = data['NumberMonitors'].replace('More than 4', '5')
data['NumberMonitors'] = data['NumberMonitors'].astype(float)
data['StackOverflowRecommend'] = data['StackOverflowRecommend'].replace('10 (Very Likely)','10')
data['StackOverflowRecommend'] = data['StackOverflowRecommend'].replace('0 (Not Likely)','0')
data['StackOverflowRecommend'] = data['StackOverflowRecommend'].astype(float)
for i in data:
    print('Name and tag in column ' + data.columns[counter] + ': ')
    print('Number of empty in column ' + data.columns[counter] + ': ' + str(data[i].isnull().sum()))
    print('Type in column ' + data.columns[counter] + ': ' + str(data[i].dtypes))
    if(str(data[i].dtypes) == 'float64'):
        print('Type of data in column ' + data.columns[counter] + ': ' + 'numeric, float64')
    else:
        if((data[i][1] == True) or (data[i][1] == False)):
            print('Type of data in column ' + data.columns[counter] + ': ' + 'binary, bool')
        else:
            print('Type of data in column ' + data.columns[counter] + ': ' + 'other, string, etc')
    print('\n---------------------------------------------------------------------------\n')
    counter = counter + 1
# Out:
# Name and tag in column Country:
# Number of empty in column Country: 412
# Type in column Country: object
# Type of data in column Country: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column Student:
# Number of empty in column Student: 3954
# Type in column Student: object
# Type of data in column Student: binary, bool
#
# ---------------------------------------------------------------------------
#
# Name and tag in column Employment:
# Number of empty in column Employment: 3534
# Type in column Employment: object
# Type of data in column Employment: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column FormalEducation:
# Number of empty in column FormalEducation: 4152
# Type in column FormalEducation: object
# Type of data in column FormalEducation: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column UndergradMajor:
# Number of empty in column UndergradMajor: 19819
# Type in column UndergradMajor: object
# Type of data in column UndergradMajor: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column CompanySize:
# Number of empty in column CompanySize: 27324
# Type in column CompanySize: object
# Type of data in column CompanySize: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column DevType:
# Number of empty in column DevType: 6757
# Type in column DevType: object
# Type of data in column DevType: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column YearsCoding:
# Number of empty in column YearsCoding: 5020
# Type in column YearsCoding: object
# Type of data in column YearsCoding: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column JobSatisfaction:
# Number of empty in column JobSatisfaction: 29579
# Type in column JobSatisfaction: object
# Type of data in column JobSatisfaction: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column CareerSatisfaction:
# Number of empty in column CareerSatisfaction: 22351
# Type in column CareerSatisfaction: object
# Type of data in column CareerSatisfaction: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column HopeFiveYears:
# Number of empty in column HopeFiveYears: 23137
# Type in column HopeFiveYears: object
# Type of data in column HopeFiveYears: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column JobSearchStatus:
# Number of empty in column JobSearchStatus: 19367
# Type in column JobSearchStatus: object
# Type of data in column JobSearchStatus: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column LastNewJob:
# Number of empty in column LastNewJob: 19966
# Type in column LastNewJob: object
# Type of data in column LastNewJob: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column SalaryType:
# Number of empty in column SalaryType: 47785
# Type in column SalaryType: object
# Type of data in column SalaryType: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column ConvertedSalary:
# Number of empty in column ConvertedSalary: 51153
# Type in column ConvertedSalary: float64
# Type of data in column ConvertedSalary: numeric, float64
#
# ---------------------------------------------------------------------------
#
# Name and tag in column LanguageWorkedWith:
# Number of empty in column LanguageWorkedWith: 20521
# Type in column LanguageWorkedWith: object
# Type of data in column LanguageWorkedWith: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column OperatingSystem:
# Number of empty in column OperatingSystem: 22676
# Type in column OperatingSystem: object
# Type of data in column OperatingSystem: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column NumberMonitors:
# Number of empty in column NumberMonitors: 22457
# Type in column NumberMonitors: float64
# Type of data in column NumberMonitors: numeric, float64
#
# ---------------------------------------------------------------------------
#
# Name and tag in column StackOverflowRecommend:
# Number of empty in column StackOverflowRecommend: 22366
# Type in column StackOverflowRecommend: float64
# Type of data in column StackOverflowRecommend: numeric, float64
#
# ---------------------------------------------------------------------------
#
# Name and tag in column StackOverflowVisit:
# Number of empty in column StackOverflowVisit: 22044
# Type in column StackOverflowVisit: object
# Type of data in column StackOverflowVisit: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column HoursComputer:
# Number of empty in column HoursComputer: 26722
# Type in column HoursComputer: object
# Type of data in column HoursComputer: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column HoursOutside:
# Number of empty in column HoursOutside: 26831
# Type in column HoursOutside: object
# Type of data in column HoursOutside: other, string, etc
#
# ---------------------------------------------------------------------------
#
# Name and tag in column Age:
# Number of empty in column Age: 34281
# Type in column Age: object
# Type of data in column Age: other, string, etc
#
# ---------------------------------------------------------------------------

# %%
# The amount of salary for everyone on full-time job.
normalsalary = []
for index, row in data.iterrows():
    if(str(row[2]) == 'Employed part-time'):
        normalsalary.append(2 * row[14])
    elif(str(row[2]) == 'Employed full-time'):
        normalsalary.append(row[14])
    else:
        normalsalary.append(data['ConvertedSalary'].mean())
for i in range(0, len(normalsalary)):
    if(str(normalsalary[i]) == 'nan'):
        normalsalary[i] = data['ConvertedSalary'].mean()
for i in range(0, len(normalsalary)):
    normalsalary[i] = int(int(normalsalary[i]))
print(normalsalary)
# Out:
# [95780, 70841, 95780, 95780, 21426, 41671, 120000, 95780, 250000, 95780, 95780, 95780, 95780, 95780, 0, 95780, 95780, 47904, 95780, 95780, 95968, 95780, 420, 75000, 10958, 51408, 72611, 900000, 95780, 95780, 30000, 95780, 44000, 60000, 95780, 80000, 95780, 95780, 95780, 95780, 95780, 123984, 21228, 74000, 95780, 6576, 115000, 70000, 95780, 90000, 95780, 115000, 95780, 73428, 95780, 95780, 128507, 26424, 95780, 95780, 95780, 95780, 120000, 48955, 95780, 19500, 95780, 95780, 95780, 95780, 85708, 95780, 95780, 36000, 95780, 95780, 64116, 95780, 95780, 45144, 32412, 52627, 82648, 95780, 95780, 78000, 120000, 42456, 95780, 95780, 30000, 26436, 95780, 34440, 95780, 4128, 95780, 95780, 95780, 95780, 141625, 95780, 95780, 71095, 95780, 35244, 4696, 95780, 95780, 95780, 95780, 120000, 95780, 69452, 63896, 95780, 63628, 110000, 95780, 95780, 28680, 95780, 95780, 9768, 21418, 916764, 30597, 59980, 228888, 95780, 95780, 42348, 48955, 37572, 34726, 95780, 55392, 95780, 95780, 27708, 70000, 59172, 59980, 91969, 9984, 55075, 95780, 87971, 95780, 7512, 105000, 95780, 95780, 105000, 95780, 95780, 95780, 95780, 36000, 120000, 123360, 42836, 29532, 95780, 64866, 95780, 77000, 36000, 95780, 97000, 95780, 45838, 95780, 59880, 95780, 48955, 95780, 6732, 125000, 72469, 95780, 95780, 11808, 95780, 39648, 95780, 95780, 62507, 29373, 95780, 74482, 95780, 95780, 25920, 95780, 73433, 95780, 1080000, 90288, 122388, 37084, 23496, 100000, 95780, 60000, 95780, 95780, 10440, 95780, 95780, 95780, 46992, 61580, 26612, 95780, 18780, 95780, 95780, 23440, 42836, 95780, 3569, 95780, 95780, 95780, 1140000, 1879, 95780, 95780, 79552, 95780, 46963, 95780, 8140, 95780, 81000, 440592, 95780, 20244, 95780, 95780, 33528, 65000, 21708, 58746, 95780, 52783, 32316, 95780, 95780, 95780, 8496, 45895, 95780, 60000, 9552, 4512, 38510, 95780, 105000, 47227, 20808, 95780, 95780, 100000, 29373, 95780, 33972, 95780, 4000000, 74856, 44060, 140000, 95780, 7140, 95780, 95780, 59500, 95780, 95780, 95780, 95780, 56172, 2820, 51394, 95780, 83342, 95780, 95780, 95780, 95780, 95780, 62507, 55075, 80784, 95780, 95780, 42456, 95780, 95780, 72500, 95780, 65285, 95780, 95780, 75000, 58752, 70000, 185000, 37940, 95780, 21916, 125000, 25000, 8448, 95780, 32000, 3757, 22884, 75504, 52404, 95780, 187152, 52872, 126403, 95780, 95780, 95780, 235000, 95780, 95780, 95780, 95780, 95780, 55562, 125000, 36716, 13284, 87971, 10572, 48955, 155000, 95780, 95780, 95780, 95780, 52339, 113000, 127000, 56544, 47000, 110000, 95780, 11741, 20000, 64000, 9840, 95780, 90000, 43482, 63529, 95780, 140000, 96000, 14340, 48313, 42456, 95780, 95780, 95780, 39776, 94600, 12480, 95780, 95780, 95780, 95780, 87768, 95780, 62507, 95780, 44064, 30597, 95780, 119458, 95780, 22560, 105000, 95780, 95780, 80000, 95780, 95780, 36720, 95780, 31664, 1000000, 38184, 54507, 34726, 95780, 106000, 63642, 86120, 4745, 95780, 2000000, 17676, 95780, 52404, 95780, 95780, 95780, 95780, 1884, 95780, 587460, 93840, 47304, 85671, 95780, 90000, 91000, 95780, 112000, 57170, 95780, 120000, 130000, 58340, 78000, 95780, 95780, 95780, 95780, 44064, 102816, 95780, 30840, 41612, 95780, 791124, 95780, 55000, 95780, 75000, 60391, 41124, 10958, 95780, 95780, 95780, 95780, 70000, 3900, 95780, 95780, 5479, 95780, 95780, 95780, 96626, 95780, 95780, 12000, 58000, 280000, 106956, 95780, 53000, 90039, 95780, 162100, 68000, 75000, 684000, 95780, 95780, 95780, 53144, 95780, 95780, 95780, 95780, 95780, 22560, 36720, 80000, 0, 95780, 51408, 95780, 95780, 45897, 14089, 18000, 3600, 12524, 3914, 13212, 69452, 95780, 25008, 95780, 96626, 199950, 95780, 34269, 60216, 95780, 95780, 73433, 40282, 71976, 95780, 95780, 95780, 63979, 12524, 14688, 3744, 66084, 95780, 2000000, 95780, 20000, 95780, 40392, 95780, 95780, 2000000, 95780, 1500, 36005, 104030, 80521, 80000, 136500, 171343, 95780, 44064, 99468, 46992, 27696, 48955, 140000, 9396, 95780, 95780, 95780, 140000, 936, 110000, 7608, 95780, 105000, 104269, 11647, 95780, 95780, 95780, 46992, 95780, 38184, 95780, 55000, 6384, ...

# %%
data.insert(15, 'Normal Salary', normalsalary, True)
data
# Out:
#                        Country Student  \
# Respondent
# 1                        Kenya   False
# 3               United Kingdom   False
# 4                United States   False
# 5                United States   False
# 7                 South Africa    True
# ...                        ...     ...
# 101513           United States     NaN
# 101531                   Spain    True
# 101541                   India    True
# 101544      Russian Federation   False
# 101548                Cambodia     NaN
#
#                                                    Employment  \
# Respondent
# 1                                          Employed part-time
# 3                                          Employed full-time
# 4                                          Employed full-time
# 5                                          Employed full-time
# 7                                          Employed full-time
# ...                                                       ...
# 101513                                                    NaN
# 101531                     Not employed, but looking for work
# 101541                                     Employed full-time
# 101544      Independent contractor, freelancer, or self-em...
# 101548                                                    NaN
#
#                                               FormalEducation  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                                            Associate degree
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7           Some college/university study without earning ...
# ...                                                       ...
# 101513                                                    NaN
# 101531                                                    NaN
# 101541               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 101544      Some college/university study without earning ...
# 101548                                                    NaN
#
#                                                UndergradMajor  \
# Respondent
# 1                                   Mathematics or statistics
# 3           A natural science (ex. biology, chemistry, phy...
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 7           Computer science, computer engineering, or sof...
# ...                                                       ...
# 101513                                                    NaN
# 101531                                                    NaN
# 101541                                                    NaN
# 101544                                                    NaN
# 101548                                                    NaN
#
#                          CompanySize  \
# Respondent
# 1                 20 to 99 employees
# 3           10,000 or more employees
# 4                 20 to 99 employees
# 5               100 to 499 employees
# 7           10,000 or more employees
# ...                              ...
# 101513                           NaN
# 101531                           NaN
# 101541                           NaN
# 101544                           NaN
# 101548                           NaN
#
#                                                       DevType  \
# Respondent
# 1                                        Full-stack developer
# 3           Database administrator;DevOps specialist;Full-...
# 4                    Engineering manager;Full-stack developer
# 5                                        Full-stack developer
# 7           Data or business analyst;Desktop or enterprise...
# ...                                                       ...
# 101513                                                    NaN
# 101531                 Back-end developer;Front-end developer
# 101541                                                    NaN
# 101544                                                    NaN
# 101548                                                    NaN
#
#                  YearsCoding                     JobSatisfaction  \
# Respondent
# 1                  3-5 years                 Extremely satisfied
# 3           30 or more years             Moderately dissatisfied
# 4                24-26 years                Moderately satisfied
# 5                18-20 years  Neither satisfied nor dissatisfied
# 7                  6-8 years                  Slightly satisfied
# ...                      ...                                 ...
# 101513                   NaN                                 NaN
# 101531             0-2 years                                 NaN
# 101541                   NaN                                 NaN
# 101544                   NaN                                 NaN
# 101548                   NaN                                 NaN
#
#                             CareerSatisfaction  ... ConvertedSalary  \
# Respondent                                      ...
# 1                          Extremely satisfied  ...             NaN
# 3           Neither satisfied nor dissatisfied  ...         70841.0
# 4                         Moderately satisfied  ...             NaN
# 5                        Slightly dissatisfied  ...             NaN
# 7                         Moderately satisfied  ...         21426.0
# ...                                        ...  ...             ...
# 101513                                     NaN  ...             NaN
# 101531                                     NaN  ...             NaN
# 101541                                     NaN  ...             NaN
# 101544                                     NaN  ...             NaN
# 101548                                     NaN  ...             NaN
#
#            Normal Salary                                LanguageWorkedWith  \
# Respondent
# 1                  95780                        JavaScript;Python;HTML;CSS
# 3                  70841                      JavaScript;Python;Bash/Shell
# 4                  95780                                               NaN
# 5                  95780  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 7                  21426                C;C++;Java;Matlab;R;SQL;Bash/Shell
# ...                  ...                                               ...
# 101513             95780                                               NaN
# 101531             95780                                               NaN
# 101541             95780                                               NaN
# 101544             95780                                               NaN
# 101548             95780                                               NaN
#
#            OperatingSystem  NumberMonitors  StackOverflowRecommend  \
# Respondent
# 1              Linux-based             1.0                    10.0
# 3              Linux-based             2.0                    10.0
# 4                      NaN             NaN                     NaN
# 5                  Windows             2.0                    10.0
# 7                  Windows             2.0                    10.0
# ...                    ...             ...                     ...
# 101513                 NaN             NaN                     NaN
# 101531                 NaN             NaN                     NaN
# 101541                 NaN             NaN                     NaN
# 101544                 NaN             NaN                     NaN
# 101548                 NaN             NaN                     NaN
#
#                          StackOverflowVisit  HoursComputer  \
# Respondent
# 1                    Multiple times per day   9 - 12 hours
# 3           A few times per month or weekly    5 - 8 hours
# 4                                       NaN            NaN
# 5                      A few times per week   9 - 12 hours
# 7                     Daily or almost daily  Over 12 hours
# ...                                     ...            ...
# 101513                                  NaN            NaN
# 101531                                  NaN            NaN
# 101541                                  NaN            NaN
# 101544                                  NaN            NaN
# 101548                                  NaN            NaN
#
#                     HoursOutside                Age
# Respondent
# 1                    1 - 2 hours  25 - 34 years old
# 3                30 - 59 minutes  35 - 44 years old
# 4                            NaN                NaN
# 5           Less than 30 minutes  35 - 44 years old
# 7                    1 - 2 hours  18 - 24 years old
# ...                          ...                ...
# 101513                       NaN                NaN
# 101531                       NaN                NaN
# 101541                       NaN                NaN
# 101544                       NaN                NaN
# 101548                       NaN                NaN
#
# [98855 rows x 24 columns]

# %%
# Chages interval to category.
data['CompanySize'] = data['CompanySize'].replace('Fewer than 10 employees', 'Enthusiasts')
data['CompanySize'] = data['CompanySize'].replace('10 to 19 employees', 'Medium Group')
data['CompanySize'] = data['CompanySize'].replace('20 to 99 employees', 'Small Company')
data['CompanySize'] = data['CompanySize'].replace('100 to 499 employees', 'Standart Company')
data['CompanySize'] = data['CompanySize'].replace('500 to 999 employees', 'Large Company')
data['CompanySize'] = data['CompanySize'].replace('1,000 to 4,999 employees', 'Minor Corporation')
data['CompanySize'] = data['CompanySize'].replace('5,000 to 9,999 employees', 'Average Corporation')
data['CompanySize'] = data['CompanySize'].replace('10,000 or more employees', 'Global Corporation')
data
# Out:
#                        Country Student  \
# Respondent
# 1                        Kenya   False
# 3               United Kingdom   False
# 4                United States   False
# 5                United States   False
# 7                 South Africa    True
# ...                        ...     ...
# 101513           United States     NaN
# 101531                   Spain    True
# 101541                   India    True
# 101544      Russian Federation   False
# 101548                Cambodia     NaN
#
#                                                    Employment  \
# Respondent
# 1                                          Employed part-time
# 3                                          Employed full-time
# 4                                          Employed full-time
# 5                                          Employed full-time
# 7                                          Employed full-time
# ...                                                       ...
# 101513                                                    NaN
# 101531                     Not employed, but looking for work
# 101541                                     Employed full-time
# 101544      Independent contractor, freelancer, or self-em...
# 101548                                                    NaN
#
#                                               FormalEducation  \
# Respondent
# 1                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                                            Associate degree
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7           Some college/university study without earning ...
# ...                                                       ...
# 101513                                                    NaN
# 101531                                                    NaN
# 101541               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 101544      Some college/university study without earning ...
# 101548                                                    NaN
#
#                                                UndergradMajor  \
# Respondent
# 1                                   Mathematics or statistics
# 3           A natural science (ex. biology, chemistry, phy...
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 7           Computer science, computer engineering, or sof...
# ...                                                       ...
# 101513                                                    NaN
# 101531                                                    NaN
# 101541                                                    NaN
# 101544                                                    NaN
# 101548                                                    NaN
#
#                    CompanySize  \
# Respondent
# 1                Small Company
# 3           Global Corporation
# 4                Small Company
# 5             Standart Company
# 7           Global Corporation
# ...                        ...
# 101513                     NaN
# 101531                     NaN
# 101541                     NaN
# 101544                     NaN
# 101548                     NaN
#
#                                                       DevType  \
# Respondent
# 1                                        Full-stack developer
# 3           Database administrator;DevOps specialist;Full-...
# 4                    Engineering manager;Full-stack developer
# 5                                        Full-stack developer
# 7           Data or business analyst;Desktop or enterprise...
# ...                                                       ...
# 101513                                                    NaN
# 101531                 Back-end developer;Front-end developer
# 101541                                                    NaN
# 101544                                                    NaN
# 101548                                                    NaN
#
#                  YearsCoding                     JobSatisfaction  \
# Respondent
# 1                  3-5 years                 Extremely satisfied
# 3           30 or more years             Moderately dissatisfied
# 4                24-26 years                Moderately satisfied
# 5                18-20 years  Neither satisfied nor dissatisfied
# 7                  6-8 years                  Slightly satisfied
# ...                      ...                                 ...
# 101513                   NaN                                 NaN
# 101531             0-2 years                                 NaN
# 101541                   NaN                                 NaN
# 101544                   NaN                                 NaN
# 101548                   NaN                                 NaN
#
#                             CareerSatisfaction  ... ConvertedSalary  \
# Respondent                                      ...
# 1                          Extremely satisfied  ...             NaN
# 3           Neither satisfied nor dissatisfied  ...         70841.0
# 4                         Moderately satisfied  ...             NaN
# 5                        Slightly dissatisfied  ...             NaN
# 7                         Moderately satisfied  ...         21426.0
# ...                                        ...  ...             ...
# 101513                                     NaN  ...             NaN
# 101531                                     NaN  ...             NaN
# 101541                                     NaN  ...             NaN
# 101544                                     NaN  ...             NaN
# 101548                                     NaN  ...             NaN
#
#            Normal Salary                                LanguageWorkedWith  \
# Respondent
# 1                  95780                        JavaScript;Python;HTML;CSS
# 3                  70841                      JavaScript;Python;Bash/Shell
# 4                  95780                                               NaN
# 5                  95780  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 7                  21426                C;C++;Java;Matlab;R;SQL;Bash/Shell
# ...                  ...                                               ...
# 101513             95780                                               NaN
# 101531             95780                                               NaN
# 101541             95780                                               NaN
# 101544             95780                                               NaN
# 101548             95780                                               NaN
#
#            OperatingSystem  NumberMonitors  StackOverflowRecommend  \
# Respondent
# 1              Linux-based             1.0                    10.0
# 3              Linux-based             2.0                    10.0
# 4                      NaN             NaN                     NaN
# 5                  Windows             2.0                    10.0
# 7                  Windows             2.0                    10.0
# ...                    ...             ...                     ...
# 101513                 NaN             NaN                     NaN
# 101531                 NaN             NaN                     NaN
# 101541                 NaN             NaN                     NaN
# 101544                 NaN             NaN                     NaN
# 101548                 NaN             NaN                     NaN
#
#                          StackOverflowVisit  HoursComputer  \
# Respondent
# 1                    Multiple times per day   9 - 12 hours
# 3           A few times per month or weekly    5 - 8 hours
# 4                                       NaN            NaN
# 5                      A few times per week   9 - 12 hours
# 7                     Daily or almost daily  Over 12 hours
# ...                                     ...            ...
# 101513                                  NaN            NaN
# 101531                                  NaN            NaN
# 101541                                  NaN            NaN
# 101544                                  NaN            NaN
# 101548                                  NaN            NaN
#
#                     HoursOutside                Age
# Respondent
# 1                    1 - 2 hours  25 - 34 years old
# 3                30 - 59 minutes  35 - 44 years old
# 4                            NaN                NaN
# 5           Less than 30 minutes  35 - 44 years old
# 7                    1 - 2 hours  18 - 24 years old
# ...                          ...                ...
# 101513                       NaN                NaN
# 101531                       NaN                NaN
# 101541                       NaN                NaN
# 101544                       NaN                NaN
# 101548                       NaN                NaN
#
# [98855 rows x 24 columns]

# %%
# Slice and transpose.
dataslice = data.loc[10:20, 'CompanySize':'CareerSatisfaction']
dataslicetranspose = dataslice.transpose()
dataslicetranspose
# Out:
# Respondent                                                         10  \
# CompanySize                                              Medium Group
# DevType             Designer;Front-end developer;QA or test developer
# YearsCoding                                                 0-2 years
# JobSatisfaction                                    Slightly satisfied
# CareerSatisfaction                               Moderately satisfied
#
# Respondent                                                         11  \
# CompanySize                                          Standart Company
# DevType             Back-end developer;C-suite executive (CEO, CTO...
# YearsCoding                                          30 or more years
# JobSatisfaction                                  Moderately satisfied
# CareerSatisfaction                               Moderately satisfied
#
# Respondent                     16  \
# CompanySize         Large Company
# DevType                  Designer
# YearsCoding             0-2 years
# JobSatisfaction               NaN
# CareerSatisfaction            NaN
#
# Respondent                                                         17  \
# CompanySize                                         Minor Corporation
# DevType             Back-end developer;Database administrator;Mobi...
# YearsCoding                                                 6-8 years
# JobSatisfaction                               Moderately dissatisfied
# CareerSatisfaction                            Moderately dissatisfied
#
# Respondent                                                         18  \
# CompanySize                                          Standart Company
# DevType             Back-end developer;Front-end developer;Full-st...
# YearsCoding                                                 0-2 years
# JobSatisfaction                                                   NaN
# CareerSatisfaction                                                NaN
#
# Respondent                                              19  \
# CompanySize                                  Small Company
# DevType             Back-end developer;Front-end developer
# YearsCoding                                      0-2 years
# JobSatisfaction                                        NaN
# CareerSatisfaction                                     NaN
#
# Respondent                                               20
# CompanySize                                   Small Company
# DevType             Back-end developer;Full-stack developer
# YearsCoding                                       3-5 years
# JobSatisfaction                         Extremely satisfied
# CareerSatisfaction                     Moderately satisfied

# %%
sorteddata = data
sorteddata.sort_values(['Normal Salary', 'HoursComputer', 'Student'], axis=0, ascending=[False, True, False], inplace=True)
sorteddata.head(20)
# Out:
#                    Country Student          Employment  \
# Respondent
# 397          United States    True  Employed part-time
# 923          United States    True  Employed part-time
# 62532        United States    True  Employed part-time
# 85645               Turkey    True  Employed part-time
# 90919        United States    True  Employed part-time
# 14239        United States   False  Employed part-time
# 39728        United States    True  Employed part-time
# 16143        United States    True  Employed part-time
# 16185        United States    True  Employed part-time
# 7943         United States    True  Employed part-time
# 44891       United Kingdom    True  Employed part-time
# 1104                 India    True  Employed full-time
# 89691             Malaysia    True  Employed part-time
# 13395        United States   False  Employed full-time
# 88768        United States   False  Employed full-time
# 4463         United States    True  Employed full-time
# 22681        United States    True  Employed full-time
# 24401                Chile    True  Employed full-time
# 30214               Brazil    True  Employed part-time
# 30620        United States    True  Employed full-time
#
#                                               FormalEducation  \
# Respondent
# 397         Some college/university study without earning ...
# 923         Some college/university study without earning ...
# 62532             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 85645                      Professional degree (JD, MD, etc.)
# 90919                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 14239                      Professional degree (JD, MD, etc.)
# 39728       Some college/university study without earning ...
# 16143                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 16185       Some college/university study without earning ...
# 7943              Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 44891             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 1104                                                      NaN
# 89691       Some college/university study without earning ...
# 13395                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88768             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4463                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 22681                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 24401                  I never completed any formal education
# 30214                      Professional degree (JD, MD, etc.)
# 30620             Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 397         Another engineering discipline (ex. civil, ele...
# 923         Computer science, computer engineering, or sof...
# 62532       A natural science (ex. biology, chemistry, phy...
# 85645                           Web development or web design
# 90919       Computer science, computer engineering, or sof...
# 14239       A health science (ex. nursing, pharmacy, radio...
# 39728                                                     NaN
# 16143       Computer science, computer engineering, or sof...
# 16185       Computer science, computer engineering, or sof...
# 7943        A social science (ex. anthropology, psychology...
# 44891       Computer science, computer engineering, or sof...
# 1104                                                      NaN
# 89691                               Mathematics or statistics
# 13395       Computer science, computer engineering, or sof...
# 88768       Computer science, computer engineering, or sof...
# 4463        Computer science, computer engineering, or sof...
# 22681       Computer science, computer engineering, or sof...
# 24401                                                     NaN
# 30214       Computer science, computer engineering, or sof...
# 30620       Computer science, computer engineering, or sof...
#
#                     CompanySize  \
# Respondent
# 397            Standart Company
# 923           Minor Corporation
# 62532        Global Corporation
# 85645             Small Company
# 90919             Large Company
# 14239          Standart Company
# 39728       Average Corporation
# 16143              Medium Group
# 16185               Enthusiasts
# 7943                        NaN
# 44891        Global Corporation
# 1104                        NaN
# 89691                       NaN
# 13395             Small Company
# 88768             Large Company
# 4463         Global Corporation
# 22681             Small Company
# 24401               Enthusiasts
# 30214             Small Company
# 30620             Small Company
#
#                                                       DevType  YearsCoding  \
# Respondent
# 397                              QA or test developer;Student    3-5 years
# 923         Back-end developer;Embedded applications or de...    3-5 years
# 62532           Data scientist or machine learning specialist    3-5 years
# 85645       Front-end developer;Full-stack developer;Game ...   9-11 years
# 90919       Front-end developer;Full-stack developer;Mobil...    6-8 years
# 14239                                    Full-stack developer    0-2 years
# 39728       Back-end developer;Designer;Front-end develope...    6-8 years
# 16143       Back-end developer;Data scientist or machine l...    6-8 years
# 16185            Desktop or enterprise applications developer    3-5 years
# 7943        Data or business analyst;Educator or academic ...    3-5 years
# 44891       C-suite executive (CEO, CTO, etc.);Data or bus...    3-5 years
# 1104                                                      NaN          NaN
# 89691       Database administrator;Desktop or enterprise a...    0-2 years
# 13395       Back-end developer;Desktop or enterprise appli...    6-8 years
# 88768       Back-end developer;Data or business analyst;De...   9-11 years
# 4463        Back-end developer;Desktop or enterprise appli...    6-8 years
# 22681               Back-end developer;Database administrator    3-5 years
# 24401                             Back-end developer;Designer    3-5 years
# 30214                              Back-end developer;Student    3-5 years
# 30620       Back-end developer;Designer;Desktop or enterpr...  15-17 years
#
#                                JobSatisfaction  \
# Respondent
# 397                       Moderately satisfied
# 923                         Slightly satisfied
# 62532                     Moderately satisfied
# 85645                     Moderately satisfied
# 90919                     Moderately satisfied
# 14239                     Moderately satisfied
# 39728                      Extremely satisfied
# 16143                     Moderately satisfied
# 16185                      Extremely satisfied
# 7943        Neither satisfied nor dissatisfied
# 44891                      Extremely satisfied
# 1104                    Extremely dissatisfied
# 89691       Neither satisfied nor dissatisfied
# 13395                       Slightly satisfied
# 88768                   Extremely dissatisfied
# 4463                      Moderately satisfied
# 22681                     Moderately satisfied
# 24401                   Extremely dissatisfied
# 30214                     Moderately satisfied
# 30620       Neither satisfied nor dissatisfied
#
#                             CareerSatisfaction  ... ConvertedSalary  \
# Respondent                                      ...
# 397                       Moderately satisfied  ...       2000000.0
# 923                        Extremely satisfied  ...       2000000.0
# 62532                       Slightly satisfied  ...       2000000.0
# 85645                     Moderately satisfied  ...       2000000.0
# 90919                       Slightly satisfied  ...       2000000.0
# 14239                      Extremely satisfied  ...       2000000.0
# 39728                      Extremely satisfied  ...       2000000.0
# 16143                     Moderately satisfied  ...       2000000.0
# 16185                     Moderately satisfied  ...       1800000.0
# 7943        Neither satisfied nor dissatisfied  ...       1250000.0
# 44891                     Moderately satisfied  ...       1200000.0
# 1104                    Extremely dissatisfied  ...       2000000.0
# 89691       Neither satisfied nor dissatisfied  ...       1000000.0
# 13395                       Slightly satisfied  ...       2000000.0
# 88768                   Extremely dissatisfied  ...       2000000.0
# 4463                      Moderately satisfied  ...       2000000.0
# 22681                     Moderately satisfied  ...       2000000.0
# 24401                  Moderately dissatisfied  ...       2000000.0
# 30214                     Moderately satisfied  ...       1000000.0
# 30620       Neither satisfied nor dissatisfied  ...       2000000.0
#
#            Normal Salary                                 LanguageWorkedWith  \
# Respondent
# 397              4000000            Assembly;C;C++;Matlab;Python;Bash/Shell
# 923              4000000  C;C++;Go;Java;JavaScript;Python;SQL;Swift;Type...
# 62532            4000000     JavaScript;Matlab;Python;R;HTML;CSS;Bash/Shell
# 85645            4000000  C;C++;C#;CoffeeScript;JavaScript;Perl;PHP;Pyth...
# 90919            4000000              JavaScript;Python;TypeScript;HTML;CSS
# 14239            4000000                                JavaScript;HTML;CSS
# 39728            4000000  C;C++;C#;JavaScript;PHP;Python;SQL;VBA;VB.NET;...
# 16143            4000000  Assembly;C;C++;Java;JavaScript;Matlab;Perl;PHP...
# 16185            3600000                     C;C++;JavaScript;PHP;Rust;HTML
# 7943             2500000                Matlab;Python;R;HTML;CSS;Bash/Shell
# 44891            2400000  C++;C#;Go;Java;JavaScript;Objective-C;PHP;Pyth...
# 1104             2000000                     Assembly;C;C++;C#;CoffeeScript
# 89691            2000000                                                NaN
# 13395            2000000   C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 88768            2000000                                         C#;SQL;VBA
# 4463             2000000  Java;JavaScript;PHP;Python;Ruby;Scala;SQL;Type...
# 22681            2000000  C++;Java;Perl;PHP;Python;Ruby;SQL;HTML;CSS;Bas...
# 24401            2000000                                                PHP
# 30214            2000000  Assembly;C;C++;C#;Clojure;Java;JavaScript;Ruby...
# 30620            2000000                       Java;JavaScript;SQL;HTML;CSS
#
#            OperatingSystem  NumberMonitors  StackOverflowRecommend  \
# Respondent
# 397            Linux-based             1.0                    10.0
# 923            Linux-based             2.0                    10.0
# 62532                MacOS             2.0                    10.0
# 85645              Windows             3.0                     7.0
# 90919                MacOS             2.0                    10.0
# 14239                MacOS             2.0                    10.0
# 39728              Windows             3.0                    10.0
# 16143                MacOS             2.0                    10.0
# 16185              Windows             2.0                    10.0
# 7943               Windows             2.0                    10.0
# 44891          Linux-based             5.0                    10.0
# 1104                   NaN             NaN                     0.0
# 89691              Windows             1.0                    10.0
# 13395              Windows             3.0                    10.0
# 88768              Windows             3.0                    10.0
# 4463                 MacOS             3.0                    10.0
# 22681          Linux-based             2.0                    10.0
# 24401              Windows             4.0                     2.0
# 30214          Linux-based             1.0                     4.0
# 30620              Windows             3.0                    10.0
#
#                                            StackOverflowVisit  HoursComputer  \
# Respondent
# 397                                    Multiple times per day    5 - 8 hours
# 923                                    Multiple times per day    5 - 8 hours
# 62532                                   Daily or almost daily    5 - 8 hours
# 85645                         A few times per month or weekly    5 - 8 hours
# 90919                                   Daily or almost daily    5 - 8 hours
# 14239                                  Multiple times per day    5 - 8 hours
# 39728                                    A few times per week   9 - 12 hours
# 16143                                   Daily or almost daily  Over 12 hours
# 16185                                    A few times per week   9 - 12 hours
# 7943                                    Daily or almost daily    5 - 8 hours
# 44891                                   Daily or almost daily    5 - 8 hours
# 1104                                                      NaN    1 - 4 hours
# 89691       I have never visited Stack Overflow (before to...    1 - 4 hours
# 13395                                    A few times per week    1 - 4 hours
# 88768                         A few times per month or weekly    1 - 4 hours
# 4463                                    Daily or almost daily    5 - 8 hours
# 22681                                  Multiple times per day    5 - 8 hours
# 24401                                  Multiple times per day    5 - 8 hours
# 30214                     Less than once per month or monthly    5 - 8 hours
# 30620                                  Multiple times per day    5 - 8 hours
#
#                HoursOutside                Age
# Respondent
# 397         30 - 59 minutes  18 - 24 years old
# 923             1 - 2 hours  18 - 24 years old
# 62532       30 - 59 minutes  25 - 34 years old
# 85645           3 - 4 hours                NaN
# 90919           3 - 4 hours  18 - 24 years old
# 14239       30 - 59 minutes  25 - 34 years old
# 39728           1 - 2 hours  18 - 24 years old
# 16143           3 - 4 hours  18 - 24 years old
# 16185       30 - 59 minutes  18 - 24 years old
# 7943        30 - 59 minutes  25 - 34 years old
# 44891           3 - 4 hours  18 - 24 years old
# 1104                    NaN                NaN
# 89691          Over 4 hours  25 - 34 years old
# 13395                   NaN  25 - 34 years old
# 88768       30 - 59 minutes  25 - 34 years old
# 4463            3 - 4 hours  25 - 34 years old
# 22681       30 - 59 minutes  18 - 24 years old
# 24401           3 - 4 hours  25 - 34 years old
# 30214           3 - 4 hours  18 - 24 years old
# 30620       30 - 59 minutes  35 - 44 years old
#
# [20 rows x 24 columns]

# %%
# Dependence of job satisfaction on job searching status.


# Job satisfaction: points 0-6: 0 - extremly dissastified, 6 - extremely satisfied.
# Job searching status 0-2: 0 - not looking, 2 - actively looking.


import matplotlib.pyplot as plt


data['JobSatisfaction'] = data['JobSatisfaction'].replace('Extremely dissatisfied', 0)
data['JobSatisfaction'] = data['JobSatisfaction'].replace('Moderately dissatisfied', 1)
data['JobSatisfaction'] = data['JobSatisfaction'].replace('Slightly dissatisfied', 2)
data['JobSatisfaction'] = data['JobSatisfaction'].replace('Neither satisfied nor dissatisfied', 3)
data['JobSatisfaction'] = data['JobSatisfaction'].replace('Slightly satisfied', 4)
data['JobSatisfaction'] = data['JobSatisfaction'].replace('Moderately satisfied', 5)
data['JobSatisfaction'] = data['JobSatisfaction'].replace('Extremely satisfied', 6)


data['JobSearchStatus'] = data['JobSearchStatus'].replace('I am not interested in new job opportunities', 0)
data['JobSearchStatus'] = data['JobSearchStatus'].replace('I’m not actively looking, but I am open to new opportunities', 1)
data['JobSearchStatus'] = data['JobSearchStatus'].replace('I am actively looking for a job', 2)


isga = []
cntrs = []
plott = dict()
for index, row in data.iterrows():
    try:
        k = str(int(row[8])) + str(int(row[11]))
    except:
        continue
    isga.append(k)
    if(k in plott.keys()):
        plott[k] = plott[k] + 1
    else:
        plott[k] = 1
    if(k == '02'):
        cntrs.append(row[0])

        
isga = list(set(isga))
isga.sort()
plt.xlabel('Types of people')
plt.ylabel('Number of people')
plt.title('Theory #1, Dependence of job satisfaction on job searching status')
a = []
b = []
print(isga)
for i in isga:
    a.append(i)
    b.append(plott[i])
x = [i for i in range(0, len(b))]
plt.bar(x, height = b, width=0.8, color='r')
plt.xticks(x, a)
# Out:
# ['00', '01', '02', '10', '11', '12', '20', '21', '22', '30', '31', '32', '40', '41', '42', '50', '51', '52', '60', '61', '62']
# ([<matplotlib.axis.XTick at 0x7febbb5feb80>,
#   <matplotlib.axis.XTick at 0x7febbb5feb50>,
#   <matplotlib.axis.XTick at 0x7feb9e7c1790>,
#   <matplotlib.axis.XTick at 0x7feb9e6fd130>,
#   <matplotlib.axis.XTick at 0x7feb9e6fd640>,
#   <matplotlib.axis.XTick at 0x7feb9e6fd7f0>,
#   <matplotlib.axis.XTick at 0x7feb9e6fdd00>,
#   <matplotlib.axis.XTick at 0x7feb9fc39250>,
#   <matplotlib.axis.XTick at 0x7feb9fc39760>,
#   <matplotlib.axis.XTick at 0x7feb9fc39c70>,
#   <matplotlib.axis.XTick at 0x7feb9fc3a1f0>,
#   <matplotlib.axis.XTick at 0x7feb9fc3a700>,
#   <matplotlib.axis.XTick at 0x7feb9fc3ac10>,
#   <matplotlib.axis.XTick at 0x7feba20c1160>,
#   <matplotlib.axis.XTick at 0x7feb9fc3a8e0>,
#   <matplotlib.axis.XTick at 0x7feb9fc39940>,
#   <matplotlib.axis.XTick at 0x7feb9e6fd9d0>,
#   <matplotlib.axis.XTick at 0x7feba20c1700>,
#   <matplotlib.axis.XTick at 0x7feba20c1c10>,
#   <matplotlib.axis.XTick at 0x7feba20c0160>,
#   <matplotlib.axis.XTick at 0x7feba20c0670>],
#  [Text(0, 0, '00'),
#   Text(0, 0, '01'),
#   Text(0, 0, '02'),
#   Text(0, 0, '10'),
#   Text(0, 0, '11'),
#   Text(0, 0, '12'),
#   Text(0, 0, '20'),
#   Text(0, 0, '21'),
#   Text(0, 0, '22'),
#   Text(0, 0, '30'),
#   Text(0, 0, '31'),
#   Text(0, 0, '32'),
#   Text(0, 0, '40'),
#   Text(0, 0, '41'),
#   Text(0, 0, '42'),
#   Text(0, 0, '50'),
#   Text(0, 0, '51'),
#   Text(0, 0, '52'),
#   Text(0, 0, '60'),
#   Text(0, 0, '61'),
#   Text(0, 0, '62')])

# %%
cntrs.sort()
mc = cntrs[0]
for i in range(0, len(cntrs)):
    if(cntrs.count(mc) < cntrs.count(cntrs[i])):
        mc = cntrs[i]
print(mc)
plt.hist(cntrs, color='b')
# Out:
# United States
# (array([ 54.,  93.,  27., 306.,  58.,  26.,  44.,  44.,  35., 321.]),
#  array([ 0. ,  9.3, 18.6, 27.9, 37.2, 46.5, 55.8, 65.1, 74.4, 83.7, 93. ]),
#  <a list of 10 Patch objects>)

# %%
# Dependence of being student on worktime schedule.


# 0 means totaly free person.
# 1 means no work student.
# 2 means part-time work adult.
# 3 means full-time work adult.
# 4 means part-time work student.
# 5 means full-time work student.


datanew = data[['Student', 'Employment']]
workstudy = []
for index, row in datanew.iterrows():
    if(row[0]):
        # Student.
        if(row[1] == 'Employed full-time'):
            workstudy.append(5)
        elif(row[1] == 'Employed part-time'):
            workstudy.append(4)
        else:
            workstudy.append(1)
            
    else:
        # Not student.
        if(row[1] == 'Employed full-time'):
            workstudy.append(3)
        elif(row[1] == 'Employed part-time'):
            workstudy.append(2)
        else:
            workstudy.append(0)


workstudy.sort()
plt.xlabel('Types of worktime schedule')
plt.ylabel('Number of people')
plt.title('Dependence of being student on worktime schedule')
a = [0, 0, 0, 0, 0, 0]
for i in range(0, 6):
    a[i] = workstudy.count(i)
x = [i for i in range(0, len(a))]
plt.bar(x, height = a, width=0.8, color='g')
# Out:
# <BarContainer object of 6 artists>

# %%
# Dependence of worktime on salary.


import random


tisaldata = data[['ConvertedSalary', 'HoursComputer']]
tisaldata = tisaldata[tisaldata['ConvertedSalary'] < 800000]
salary = []
hours = []
for index, row in tisaldata.iterrows():
    if('nan' in (str(row[0]) + str(row[1]))):
        continue
    salary.append(row[0])
    if(row[1] == 'Over 12 hours'):
        hours.append(random.randint(12, 16))
    elif(row[1] == '9 - 12 hours'):
        hours.append(random.randint(9, 12))
    elif(row[1] == '5 - 8 hours'):
        hours.append(random.randint(5, 8))
    elif(row[1] == '1 - 4 hours'):
        hours.append(random.randint(1, 4))
    elif(row[1] == 'Less than 1 hour'):
        hours.append(1)
        
        
plt.xlabel('Number of programming hours')
plt.ylabel('Annual salary in $')
plt.title('Dependence of worktime on salary')
plt.plot(hours, salary, 'o')

# %%
# Most of programmers are younger then 50.


y9 = 0
y21 = 0
y30 = 0
y40 = 0
y50 = 0
y60 = 0
y70 = 0
for index, row in data.iterrows():
    if(str(row[23]) == 'Under 18 years old'):
        y9 = y9 + 1
    elif(str(row[23]) == '18 - 24 years old'):
        y21 = y21 + 1
    elif(str(row[23]) == '25 - 34 years old'):
        y30 = y30 + 1
    elif(str(row[23]) == '35 - 44 years old'):
        y40 = y40 + 1
    elif(str(row[23]) == '45 - 54 years old'):
        y50 = y50 + 1
    elif(str(row[23]) == '55 - 64 years old'):
        y60 = y60 + 1
    elif(str(row[23]) == '65 years or older'):
        y70 = y70 + 1


print([y9, y21, y30, y40, y50, y60, y70])
plt.xlabel('Average age')
plt.ylabel('Number of people')
plt.title('Most of programmers are younger then 50')
plt.plot([9, 21, 30, 40, 50, 60, 70], [y9, y21, y30, y40, y50, y60, y70], 'r')
# Out:
# [1638, 15249, 31759, 11477, 3313, 959, 179]

# %%
# Students are mostly people of age 18-24 years.


ys9 = 0
ys21 = 0
ys30 = 0
ys40 = 0
ys50 = 0
ys60 = 0
ys70 = 0
for index, row in data.iterrows():
    if(row[1]):
        if(str(row[23]) == 'Under 18 years old'):
            ys9 = ys9 + 1
        elif(str(row[23]) == '18 - 24 years old'):
            ys21 = ys21 + 1
        elif(str(row[23]) == '25 - 34 years old'):
            ys30 = ys30 + 1
        elif(str(row[23]) == '35 - 44 years old'):
            ys40 = ys40 + 1
        elif(str(row[23]) == '45 - 54 years old'):
            ys50 = ys50 + 1
        elif(str(row[23]) == '55 - 64 years old'):
            ys60 = ys60 + 1
        elif(str(row[23]) == '65 years or older'):
            ys70 = ys70 + 1


print([ys9, ys21, ys30, ys40, ys50, ys60, ys70])
plt.xlabel('Average age')
plt.ylabel('Number of people')
plt.title('Students are mostly people of age 18-24 years')
plt.plot([9, 21, 30, 40, 50, 60, 70], [ys9, ys21, ys30, ys40, ys50, ys60, ys70], 'g')
# Out:
# [362, 7894, 5438, 885, 165, 50, 20]

# %%
# Most popular programming language is Python.


langs = dict()
for index, row in data.iterrows():
    if(str(row[16]) == 'nan'):
        continue
    line = row[16].split(';')
    for j in line:
        if(j in langs.keys()):
            langs[j] = langs[j] + 1
        else:
            langs[j] = 1


langnm = []
langnum = []
l = []
lll = []
for i in langs.keys():
    langnm.append([len(langnm), i])
    langnum.append(langs[i])
    lll.append([i, int(langnum[-1])])


lll = sorted(lll, key = lambda z: -z[1])
for i in range(0, len(lll)):
    print(*lll[i])
langnum = []
for i in range(0, len(lll)):
    l.append(lll[i][0])
    langnum.append(lll[i][1])
l = l[0:9]
l.append('Others')
langnum[9] = sum(langnum[9:])
langnum = langnum[0:10]
plt.title('Most popular programming language is python')
plt.pie(labels=l, x=langnum)
# Out:
# JavaScript 54686
# HTML 53628
# CSS 50979
# SQL 44670
# Java 35521
# Bash/Shell 31172
# Python 30359
# C# 26954
# PHP 24071
# C++ 19872
# C 18042
# TypeScript 13626
# Ruby 7911
# Swift 6310
# Assembly 5760
# Go 5532
# Objective-C 5510
# VB.NET 5254
# R 4813
# Matlab 4564
# VBA 3810
# Kotlin 3508
# Scala 3420
# Groovy 3373
# Perl 3280
# Visual Basic 6 3087
# Lua 2733
# CoffeeScript 2603
# Delphi/Object Pascal 2025
# Haskell 1961
# Rust 1857
# F# 1115
# Clojure 1032
# Erlang 886
# Cobol 590
# Ocaml 470
# Julia 430
# Hack 254
# ([<matplotlib.patches.Wedge at 0x7feb909f37f0>,
#   <matplotlib.patches.Wedge at 0x7feb909f3ca0>,
#   <matplotlib.patches.Wedge at 0x7feb926c2190>,
#   <matplotlib.patches.Wedge at 0x7feb926c2610>,
#   <matplotlib.patches.Wedge at 0x7feb926c2a90>,
#   <matplotlib.patches.Wedge at 0x7feb926c2f10>,
#   <matplotlib.patches.Wedge at 0x7feb926cb3d0>,
#   <matplotlib.patches.Wedge at 0x7feb926cb850>,
#   <matplotlib.patches.Wedge at 0x7feb926cbcd0>,
#   <matplotlib.patches.Wedge at 0x7feb913e6190>],
#  [Text(1.031891345812113, 0.38105150627974993, 'JavaScript'),
#   Text(0.5431417499150658, 0.9565547760056401, 'HTML'),
#   Text(-0.1755178882445003, 1.0859067505574276, 'CSS'),
#   Text(-0.7727951522062122, 0.7828075451390192, 'SQL'),
#   Text(-1.059230129415803, 0.2967010834792842, 'Java'),
#   Text(-1.0862464361959951, -0.1734032290688386, 'Bash/Shell'),
#   Text(-0.9341250600223346, -0.5808703575138517, 'Python'),
#   Text(-0.66021218439949, -0.8798408217231422, 'C#'),
#   Text(-0.339419219209467, -1.046324325260211, 'PHP'),
#   Text(0.714017858108625, -0.8367666928732116, 'Others')])

# %%
# Windows is most popular OS for multiple screens.


oses = dict()
oses['win'] = [0, 0, 0, 0]
oses['mac'] = [0, 0, 0, 0]
oses['lin'] = [0, 0, 0, 0]
oses['unb'] = [0, 0, 0, 0]
for index, row in data.iterrows():
    if(row[17] == 'Windows'):
        try:
            oses['win'][int(row[18]) - 1] = oses['win'][int(row[18]) - 1] + 1
        except:
            continue
    elif(row[17] == 'MacOS'):
        try:
            oses['mac'][int(row[18]) - 1] = oses['mac'][int(row[18]) - 1] + 1
        except:
            continue
    elif(row[17] == 'Linux-based'):
        try:
            oses['lin'][int(row[18]) - 1] = oses['lin'][int(row[18]) - 1] + 1
        except:
            continue
    elif(row[17] == 'BSD/Unix'):
        try:
            oses['unb'][int(row[18]) - 1] = oses['unb'][int(row[18]) - 1] + 1
        except:
            continue


print(oses)
# Out:
# {'win': [10644, 20034, 6051, 548], 'mac': [7106, 9976, 2881, 156], 'lin': [6419, 8788, 1983, 186], 'unb': [49, 70, 16, 3]}

# %%
a = {'win': [10644, 20034, 6051, 548], 'mac': [7106, 9976, 2881, 156], 'lin': [6419, 8788, 1983, 186], 'unb': [49, 70, 16, 3]}
a['avg'] = []
for i in range(0, 4):
    a['avg'].append((a['win'][i] + a['mac'][i] + a['lin'][i] + a['unb'][i]) // 3)
print(a)
datamons = pd.DataFrame(a)
datamons
# Out:
# {'win': [10644, 20034, 6051, 548], 'mac': [7106, 9976, 2881, 156], 'lin': [6419, 8788, 1983, 186], 'unb': [49, 70, 16, 3], 'avg': [8072, 12956, 3643, 297]}
#      win   mac   lin  unb    avg
# 0  10644  7106  6419   49   8072
# 1  20034  9976  8788   70  12956
# 2   6051  2881  1983   16   3643
# 3    548   156   186    3    297

# %%
datamons = data.pivot_table('NumberMonitors', index=['CompanySize','Student'], columns = 'OperatingSystem')
for i in datamons.columns:
    datamons[i] = datamons[i].map(lambda x: round(x, 2))
datamons = datamons.reindex([('Enthusiasts',False),('Enthusiasts',True),
                            ('Medium Group',False),('Medium Group',True),
                            ('Small Company',False),('Small Company',True),
                            ('Standart Company',False),('Standart Company',True),
                            ('Large Company',False),('Large Company',True),
                            ('Minor Corporation',False),('Minor Corporation',True),
                            ('Average Corporation',False),('Average Corporation',True),
                            ('Global Corporation',False),('Global Corporation',True)])
datamons.to_excel('datamons.xlsx')

# %%
datarecvis = data.pivot_table('StackOverflowRecommend', index=['HoursComputer'], columns = 'StackOverflowVisit')
for i in datarecvis.columns:
    datarecvis[i] = datarecvis[i].map(lambda x: round(x, 2))
datarecvis = datarecvis.reindex(["Less than 1 hour","1 - 4 hours", "5 - 8 hours", "9 - 12 hours","Over 12 hours"])
datarecvis = datarecvis[['I have never visited Stack Overflow (before today)','Less than once per month or monthly','A few times per month or weekly','A few times per week','Daily or almost daily','Multiple times per day']]
datarecvis.to_excel('datarecvis.xlsx')

# %%
datahoyesalary = data.pivot_table('ConvertedSalary', index=['YearsCoding'], columns = 'HoursComputer')
for i in datahoyesalary.columns:
    datahoyesalary[i] = datahoyesalary[i].map(lambda x: round(x, 2))
datahoyesalary = datahoyesalary.sort_values(by=['9 - 12 hours'])
datahoyesalary.to_excel('datahoyesalary.xlsx')

# %%
data.corr(method='pearson').to_excel('datacorr.xlsx')
